# %% [markdown]
# ## NIMOハンズオン (関数の最適化)

# %%
import nimo

# %% [markdown]
# ### AIとロボットのサイクルの回数を設定

# %%
CyclesNum = 51

# %% [markdown]
# ### 目的関数の次元を設定

# %%
ObjectivesNum = 1

# %% [markdown]
# ### 実験条件候補データファイル名および提案条件のファイル名を設定

# %%
candidates_file = "./candidates_SO_Sphere.csv"

proposals_file = "./proposals.csv"

# %% [markdown]
# ### 結果を格納する場所を作成

# %%
res_history = nimo.history(input_file = candidates_file,
                             num_objectives = ObjectivesNum)

# %% [markdown]
# ### 最適化計算

# %%
for K in range(CyclesNum):

    #最初のサイクルではランダムに実験条件を提案させる
    if K == 0:
        nimo.selection(method = "RE",
                       input_file = candidates_file,
                       output_file = proposals_file,
                       num_objectives = ObjectivesNum,
                       num_proposals = 5,
                       re_seed = 111)

    #2回目以降のサイクルではAIを使用して実験条件を提案
    #PHYSBO: ベイズ最適化
    #BLOX: 無目的探索
    #PDC: 相図探索
    #RE: ランダム
    else:
        nimo.selection(method = "PHYSBO",
                       input_file = candidates_file,
                       output_file = proposals_file,
                       num_objectives = ObjectivesNum,
                       num_proposals = 1)

    #実験条件に従い，ロボット実験のインプットファイルを作成する
    #今回は，inputfile.txtファイルを作成するだけのモジュール
    import preparation_input_functions
    preparation_input_functions.ORIGINAL(input_file = proposals_file,
                                         input_folder = "./").perform()


    #実験終了後，測定データを解析し，目的関数をアップデートする
    #今回は，関数値を計算し，目的関数とするanalysis_output_functions.pyを利用する
    import analysis_output_functions_SO_Sphere
    analysis_output_functions_SO_Sphere.ORIGINAL(input_file = proposals_file,
                                       output_file = candidates_file,
                                       num_objectives = ObjectivesNum,
                                       output_folder = "./").perform()

    #結果をプロットするためのhistoryを格納する
    res_history = nimo.history(input_file = candidates_file,
                               num_objectives = ObjectivesNum,
                               itt = K,
                               history_file = res_history)

    #結果のヒストグラムを作成するモジュールを読み出す
    if K % 5 == 0:
        import time
        time.sleep(1)
        nimo.visualization.plot_distribution.plot(input_file = candidates_file,
                                                  num_objectives = ObjectivesNum,
                                                  fig_folder = "./fig")

    #結果の相図を作成するモジュールを読み出す
    #if K % 5 == 0:
    #    import time
    #    time.sleep(1)
    #    nimo.visualization.plot_phase_diagram.plot(input_file = candidates_file,
    #                                               fig_folder = "./fig")
# Out:
# Start selection of proposals by RE!
# Proposals
# ###
# number = 1
# actions =  873
# proposal =  [-1.32 -1.76]
# ###
# ###
# number = 2
# actions =  1297
# proposal =  [-1.   -1.12]
# ###
# ###
# number = 3
# actions =  2028
# proposal =  [-0.44 -0.44]
# ###
# ###
# number = 4
# actions =  796
# proposal =  [-1.4  -0.76]
# ###
# ###
# number = 5
# actions =  1632
# proposal =  [-0.72 -2.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 7.093138668377129
# 50 -th epoch marginal likelihood 6.8023830566928005
# 100 -th epoch marginal likelihood 6.530427667563382
# 150 -th epoch marginal likelihood 6.27436070961169
# 200 -th epoch marginal likelihood 6.031225756015209
# 250 -th epoch marginal likelihood 5.798694638496138
# 300 -th epoch marginal likelihood 5.574929417961156
# 350 -th epoch marginal likelihood 5.358473805348797
# 400 -th epoch marginal likelihood 5.148173644277437
# 450 -th epoch marginal likelihood 4.943117139682981
# 500 -th epoch marginal likelihood 4.742588513414388
# Done
#
# Proposals
# ###
# number = 1
# actions =  2037
# proposal =  [-0.44 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 7.0777981192130826
# 50 -th epoch marginal likelihood 6.750890707608789
# 100 -th epoch marginal likelihood 6.441543093920999
# 150 -th epoch marginal likelihood 6.147460455915446
# 200 -th epoch marginal likelihood 5.866203442483981
# 250 -th epoch marginal likelihood 5.595792942448714
# 300 -th epoch marginal likelihood 5.334612500864689
# 350 -th epoch marginal likelihood 5.081329627466228
# 400 -th epoch marginal likelihood 4.834838529324337
# 450 -th epoch marginal likelihood 4.594217295484452
# 500 -th epoch marginal likelihood 4.358695077555408
# Done
#
# Proposals
# ###
# number = 1
# actions =  2392
# proposal =  [-0.16 -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 7.067872774858551
# 50 -th epoch marginal likelihood 6.695294175481614
# 100 -th epoch marginal likelihood 6.341333150090696
# 150 -th epoch marginal likelihood 6.003603162154285
# 200 -th epoch marginal likelihood 5.679515645625247
# 250 -th epoch marginal likelihood 5.366954910709345
# 300 -th epoch marginal likelihood 5.064182680588229
# 350 -th epoch marginal likelihood 4.769758696545056
# 400 -th epoch marginal likelihood 4.482482274514135
# 450 -th epoch marginal likelihood 4.201348429160744
# 500 -th epoch marginal likelihood 3.925514297656923
# Done
#
# Proposals
# ###
# number = 1
# actions =  2591
# proposal =  [ 0.   -0.36]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 6.852634633796772
# 50 -th epoch marginal likelihood 6.434289591056671
# 100 -th epoch marginal likelihood 6.0359794365864285
# 150 -th epoch marginal likelihood 5.6545409741741395
# 200 -th epoch marginal likelihood 5.287167724437915
# 250 -th epoch marginal likelihood 4.931638960356255
# 300 -th epoch marginal likelihood 4.586177005388351
# 350 -th epoch marginal likelihood 4.249343564191726
# 400 -th epoch marginal likelihood 3.9199654422814714
# 450 -th epoch marginal likelihood 3.5970794849655015
# 500 -th epoch marginal likelihood 3.27989085915549
# Done
#
# Proposals
# ###
# number = 1
# actions =  2396
# proposal =  [-0.16  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 7.227115802931767
# 50 -th epoch marginal likelihood 6.713695404662838
# 100 -th epoch marginal likelihood 6.226048847313989
# 150 -th epoch marginal likelihood 5.760405816412427
# 200 -th epoch marginal likelihood 5.313034271805315
# 250 -th epoch marginal likelihood 4.880935610112591
# 300 -th epoch marginal likelihood 4.461732145542808
# 350 -th epoch marginal likelihood 4.053526901470253
# 400 -th epoch marginal likelihood 3.6547949680700897
# 450 -th epoch marginal likelihood 3.264301943484498
# 500 -th epoch marginal likelihood 2.8810424813860633
# Done
#
# Proposals
# ###
# number = 1
# actions =  2345
# proposal =  [-0.2  0. ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 7.785355436541523
# 50 -th epoch marginal likelihood 7.1138522634409345
# 100 -th epoch marginal likelihood 6.51195650342346
# 150 -th epoch marginal likelihood 5.935529428197273
# 200 -th epoch marginal likelihood 5.3830966485321206
# 250 -th epoch marginal likelihood 4.851514532409226
# 300 -th epoch marginal likelihood 4.337812812985482
# 350 -th epoch marginal likelihood 3.8394615364325073
# 400 -th epoch marginal likelihood 3.3543641976752285
# 450 -th epoch marginal likelihood 2.8807955082101486
# 500 -th epoch marginal likelihood 2.417335505118375
# Done
#
# Proposals
# ###
# number = 1
# actions =  2598
# proposal =  [ 0.   -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 7.17226627313329
# 50 -th epoch marginal likelihood 6.444616737659555
# 100 -th epoch marginal likelihood 5.79408500801535
# 150 -th epoch marginal likelihood 5.1682859450591305
# 200 -th epoch marginal likelihood 4.566139072067742
# 250 -th epoch marginal likelihood 3.984757129503281
# 300 -th epoch marginal likelihood 3.4212797132170074
# 350 -th epoch marginal likelihood 2.8732275640209037
# 400 -th epoch marginal likelihood 2.338528636208059
# 450 -th epoch marginal likelihood 1.8154697436392153
# 500 -th epoch marginal likelihood 1.3026371165767037
# Done
#
# Proposals
# ###
# number = 1
# actions =  2600
# proposal =  [0. 0.]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 6.532549162561732
# 50 -th epoch marginal likelihood 5.727976002901372
# 100 -th epoch marginal likelihood 5.030766500162356
# 150 -th epoch marginal likelihood 4.358368406604139
# 200 -th epoch marginal likelihood 3.7072819897758675
# 250 -th epoch marginal likelihood 3.075882286953915
# 300 -th epoch marginal likelihood 2.4618897911662634
# 350 -th epoch marginal likelihood 1.8631239856308879
# 400 -th epoch marginal likelihood 1.2776750098547058
# 450 -th epoch marginal likelihood 0.7039209506112103
# 500 -th epoch marginal likelihood 0.14050049371994522
# Done
#
# Proposals
# ###
# number = 1
# actions =  2447
# proposal =  [-0.12  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 5.943888302992768
# 50 -th epoch marginal likelihood 5.0546540276918055
# 100 -th epoch marginal likelihood 4.291828834145333
# 150 -th epoch marginal likelihood 3.5593913128280414
# 200 -th epoch marginal likelihood 2.8483357318489873
# 250 -th epoch marginal likelihood 2.157484219725907
# 300 -th epoch marginal likelihood 1.48471894187814
# 350 -th epoch marginal likelihood 0.8278867238817984
# 400 -th epoch marginal likelihood 0.18505110989040574
# 450 -th epoch marginal likelihood -0.4454569905187453
# 500 -th epoch marginal likelihood -1.0650519955005135
# Done
#
# Proposals
# ###
# number = 1
# actions =  2549
# proposal =  [-0.04  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 5.378938458445184
# 50 -th epoch marginal likelihood 4.37975027489448
# 100 -th epoch marginal likelihood 3.5407375742246625
# 150 -th epoch marginal likelihood 2.7522548058302476
# 200 -th epoch marginal likelihood 1.9845659006798009
# 250 -th epoch marginal likelihood 1.2359519049357903
# 300 -th epoch marginal likelihood 0.5051071082733616
# 350 -th epoch marginal likelihood -0.2097040503695924
# 400 -th epoch marginal likelihood -0.9102080839251636
# 450 -th epoch marginal likelihood -1.5979738641050423
# 500 -th epoch marginal likelihood -2.274375237017062
# Done
#
# Proposals
# ###
# number = 1
# actions =  2599
# proposal =  [ 0.   -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 4.757277220500569
# 50 -th epoch marginal likelihood 3.668391799136714
# 100 -th epoch marginal likelihood 2.754177395533987
# 150 -th epoch marginal likelihood 1.9033026143582106
# 200 -th epoch marginal likelihood 1.075664879085152
# 250 -th epoch marginal likelihood 0.26751290722949417
# 300 -th epoch marginal likelihood -0.5223237198632207
# 350 -th epoch marginal likelihood -1.2954942503517817
# 400 -th epoch marginal likelihood -2.05371405609805
# 450 -th epoch marginal likelihood -2.798574954297341
# 500 -th epoch marginal likelihood -3.5314885341593634
# Done
#
# Proposals
# ###
# number = 1
# actions =  2498
# proposal =  [-0.08  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 4.130650387307927
# 50 -th epoch marginal likelihood 2.929869723437351
# 100 -th epoch marginal likelihood 1.9250455923927507
# 150 -th epoch marginal likelihood 1.0093179100411662
# 200 -th epoch marginal likelihood 0.12441641185716179
# 250 -th epoch marginal likelihood -0.7411786616138878
# 300 -th epoch marginal likelihood -1.5889182975137492
# 350 -th epoch marginal likelihood -2.4200439704671766
# 400 -th epoch marginal likelihood -3.2360258457996807
# 450 -th epoch marginal likelihood -4.03832523518945
# 500 -th epoch marginal likelihood -4.828289193425185
# Done
#
# Proposals
# ###
# number = 1
# actions =  2548
# proposal =  [-0.04 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 3.312525017448868
# 50 -th epoch marginal likelihood 2.0416489144577348
# 100 -th epoch marginal likelihood 0.9721428633894025
# 150 -th epoch marginal likelihood -0.0038335433597120883
# 200 -th epoch marginal likelihood -0.946940109511047
# 250 -th epoch marginal likelihood -1.8698098222654211
# 300 -th epoch marginal likelihood -2.774108220840473
# 350 -th epoch marginal likelihood -3.6611468759090124
# 400 -th epoch marginal likelihood -4.532462578708435
# 450 -th epoch marginal likelihood -5.3895806596504405
# 500 -th epoch marginal likelihood -6.233905982143815
# Done
#
# Proposals
# ###
# number = 1
# actions =  2394
# proposal =  [-0.16 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 2.4482140703352346
# 50 -th epoch marginal likelihood 1.116429495496286
# 100 -th epoch marginal likelihood -0.011390347981294902
# 150 -th epoch marginal likelihood -1.0480326681657406
# 200 -th epoch marginal likelihood -2.0523574475972577
# 250 -th epoch marginal likelihood -3.0350585957210887
# 300 -th epoch marginal likelihood -3.9977280522267495
# 350 -th epoch marginal likelihood -4.94193809123993
# 400 -th epoch marginal likelihood -5.869445743058039
# 450 -th epoch marginal likelihood -6.7819450062543165
# 500 -th epoch marginal likelihood -7.680970863466475
# Done
#
# Proposals
# ###
# number = 1
# actions =  2497
# proposal =  [-0.08 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 1.5933649523039435
# 50 -th epoch marginal likelihood 0.18609503769689262
# 100 -th epoch marginal likelihood -1.0101239154452273
# 150 -th epoch marginal likelihood -2.1087510490383705
# 200 -th epoch marginal likelihood -3.172245403858981
# 250 -th epoch marginal likelihood -4.213100312805347
# 300 -th epoch marginal likelihood -5.233190381751679
# 350 -th epoch marginal likelihood -6.234140227377512
# 400 -th epoch marginal likelihood -7.217763267251927
# 450 -th epoch marginal likelihood -8.185814089338102
# 500 -th epoch marginal likelihood -9.139885576614654
# Done
#
# Proposals
# ###
# number = 1
# actions =  2597
# proposal =  [ 0.   -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 0.7824102868597702
# 50 -th epoch marginal likelihood -0.7185544848026417
# 100 -th epoch marginal likelihood -1.9945916772460244
# 150 -th epoch marginal likelihood -3.156797398355045
# 200 -th epoch marginal likelihood -4.276479469818788
# 250 -th epoch marginal likelihood -5.372591580060445
# 300 -th epoch marginal likelihood -6.448071376822669
# 350 -th epoch marginal likelihood -7.504380989329195
# 400 -th epoch marginal likelihood -8.54317309912076
# 450 -th epoch marginal likelihood -9.56611657878723
# 500 -th epoch marginal likelihood -10.574763674337564
# Done
#
# Proposals
# ###
# number = 1
# actions =  2592
# proposal =  [ 0.   -0.32]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -0.12096629297311168
# 50 -th epoch marginal likelihood -1.698629164346956
# 100 -th epoch marginal likelihood -3.037659433608024
# 150 -th epoch marginal likelihood -4.253206034966735
# 200 -th epoch marginal likelihood -5.422226479996111
# 250 -th epoch marginal likelihood -6.5674283503025475
# 300 -th epoch marginal likelihood -7.692538890611131
# 350 -th epoch marginal likelihood -8.798878501779075
# 400 -th epoch marginal likelihood -9.88791757438235
# 450 -th epoch marginal likelihood -10.96120481878869
# 500 -th epoch marginal likelihood -12.020216334194544
# Done
#
# Proposals
# ###
# number = 1
# actions =  2547
# proposal =  [-0.04 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -1.0994625602531016
# 50 -th epoch marginal likelihood -2.7294189709814347
# 100 -th epoch marginal likelihood -4.120658736896699
# 150 -th epoch marginal likelihood -5.394940946618665
# 200 -th epoch marginal likelihood -6.62606503015071
# 250 -th epoch marginal likelihood -7.8324544827019675
# 300 -th epoch marginal likelihood -9.016958197604652
# 350 -th epoch marginal likelihood -10.181160571737824
# 400 -th epoch marginal likelihood -11.326852974580035
# 450 -th epoch marginal likelihood -12.455828790602093
# 500 -th epoch marginal likelihood -13.569747255791754
# Done
#
# Proposals
# ###
# number = 1
# actions =  2496
# proposal =  [-0.08 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -2.079247351158509
# 50 -th epoch marginal likelihood -3.799638405051942
# 100 -th epoch marginal likelihood -5.269165647742344
# 150 -th epoch marginal likelihood -6.605268925951084
# 200 -th epoch marginal likelihood -7.889331862821011
# 250 -th epoch marginal likelihood -9.147293758930003
# 300 -th epoch marginal likelihood -10.383898087615938
# 350 -th epoch marginal likelihood -11.600660348672319
# 400 -th epoch marginal likelihood -12.799134433922557
# 450 -th epoch marginal likelihood -13.980954080108452
# 500 -th epoch marginal likelihood -15.147680275028122
# Done
#
# Proposals
# ###
# number = 1
# actions =  2546
# proposal =  [-0.04 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -3.1478696663997034
# 50 -th epoch marginal likelihood -4.914733573043879
# 100 -th epoch marginal likelihood -6.4314060313828225
# 150 -th epoch marginal likelihood -7.822849363856296
# 200 -th epoch marginal likelihood -9.166973066250112
# 250 -th epoch marginal likelihood -10.484624598080298
# 300 -th epoch marginal likelihood -11.779270606674165
# 350 -th epoch marginal likelihood -13.052615840944624
# 400 -th epoch marginal likelihood -14.306531586441105
# 450 -th epoch marginal likelihood -15.54289535892267
# 500 -th epoch marginal likelihood -16.763447616979576
# Done
#
# Proposals
# ###
# number = 1
# actions =  2446
# proposal =  [-0.12 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -4.286967519131354
# 50 -th epoch marginal likelihood -6.07032318948813
# 100 -th epoch marginal likelihood -7.617793629085902
# 150 -th epoch marginal likelihood -9.066981655152986
# 200 -th epoch marginal likelihood -10.47809630771022
# 250 -th epoch marginal likelihood -11.860365130914293
# 300 -th epoch marginal likelihood -13.216148612338284
# 350 -th epoch marginal likelihood -14.54801456537467
# 400 -th epoch marginal likelihood -15.858557247722715
# 450 -th epoch marginal likelihood -17.150150446040374
# 500 -th epoch marginal likelihood -18.424880154462407
# Done
#
# Proposals
# ###
# number = 1
# actions =  2495
# proposal =  [-0.08 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -5.233188309704593
# 50 -th epoch marginal likelihood -7.164312123947129
# 100 -th epoch marginal likelihood -8.826051761566653
# 150 -th epoch marginal likelihood -10.339790619336062
# 200 -th epoch marginal likelihood -11.793117966073297
# 250 -th epoch marginal likelihood -13.216956020722499
# 300 -th epoch marginal likelihood -14.61783766640297
# 350 -th epoch marginal likelihood -15.99760885853151
# 400 -th epoch marginal likelihood -17.357898731445555
# 450 -th epoch marginal likelihood -18.70041592630756
# 500 -th epoch marginal likelihood -20.026806756080457
# Done
#
# Proposals
# ###
# number = 1
# actions =  2395
# proposal =  [-0.16 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -6.324257108396237
# 50 -th epoch marginal likelihood -8.324745208536152
# 100 -th epoch marginal likelihood -10.049973298720253
# 150 -th epoch marginal likelihood -11.622805447533525
# 200 -th epoch marginal likelihood -13.132640776838604
# 250 -th epoch marginal likelihood -14.611833202021097
# 300 -th epoch marginal likelihood -16.067489024119777
# 350 -th epoch marginal likelihood -17.50158758234528
# 400 -th epoch marginal likelihood -18.915796852325364
# 450 -th epoch marginal likelihood -20.311857597005098
# 500 -th epoch marginal likelihood -21.69144910763062
# Done
#
# Proposals
# ###
# number = 1
# actions =  2596
# proposal =  [ 0.   -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -7.759533876388915
# 50 -th epoch marginal likelihood -9.575027412405884
# 100 -th epoch marginal likelihood -11.307537293824362
# 150 -th epoch marginal likelihood -12.972563870291605
# 200 -th epoch marginal likelihood -14.583628455173839
# 250 -th epoch marginal likelihood -16.150760614816747
# 300 -th epoch marginal likelihood -17.681563035018936
# 350 -th epoch marginal likelihood -19.181905630558404
# 400 -th epoch marginal likelihood -20.656390029621157
# 450 -th epoch marginal likelihood -22.10867138966308
# 500 -th epoch marginal likelihood -23.54168692967703
# Done
#
# Proposals
# ###
# number = 1
# actions =  2294
# proposal =  [-0.24  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -8.885260271227143
# 50 -th epoch marginal likelihood -10.756938627130355
# 100 -th epoch marginal likelihood -12.546394797877205
# 150 -th epoch marginal likelihood -14.267968943968395
# 200 -th epoch marginal likelihood -15.934942511074794
# 250 -th epoch marginal likelihood -17.55733209831714
# 300 -th epoch marginal likelihood -19.142786346290457
# 350 -th epoch marginal likelihood -20.697235682164376
# 400 -th epoch marginal likelihood -22.22534163865011
# 450 -th epoch marginal likelihood -23.73081364685143
# 500 -th epoch marginal likelihood -25.2166363698359
# Done
#
# Proposals
# ###
# number = 1
# actions =  2445
# proposal =  [-0.12 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -5.08579330350776
# 50 -th epoch marginal likelihood -8.499501588917017
# 100 -th epoch marginal likelihood -11.47097460030437
# 150 -th epoch marginal likelihood -14.096384022356116
# 200 -th epoch marginal likelihood -16.446796230655696
# 250 -th epoch marginal likelihood -18.56981100014594
# 300 -th epoch marginal likelihood -20.50602127008448
# 350 -th epoch marginal likelihood -22.29409996139996
# 400 -th epoch marginal likelihood -23.969575099060823
# 450 -th epoch marginal likelihood -25.562656516596057
# 500 -th epoch marginal likelihood -27.097273568983365
# Done
#
# Proposals
# ###
# number = 1
# actions =  2344
# proposal =  [-0.2  -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -11.227548719349818
# 50 -th epoch marginal likelihood -13.22575624733789
# 100 -th epoch marginal likelihood -15.13678062478739
# 150 -th epoch marginal likelihood -16.976285366429337
# 200 -th epoch marginal likelihood -18.758393822339592
# 250 -th epoch marginal likelihood -20.493709024465797
# 300 -th epoch marginal likelihood -22.190306057530776
# 350 -th epoch marginal likelihood -23.854434373775327
# 400 -th epoch marginal likelihood -25.490999427009523
# 450 -th epoch marginal likelihood -27.103900571524534
# 500 -th epoch marginal likelihood -28.69627269236888
# Done
#
# Proposals
# ###
# number = 1
# actions =  2595
# proposal =  [ 0.  -0.2]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -12.402676535470457
# 50 -th epoch marginal likelihood -14.46178769577202
# 100 -th epoch marginal likelihood -16.43233041184142
# 150 -th epoch marginal likelihood -18.329914952859156
# 200 -th epoch marginal likelihood -20.16891672770971
# 250 -th epoch marginal likelihood -21.96015324935077
# 300 -th epoch marginal likelihood -23.711869767440504
# 350 -th epoch marginal likelihood -25.43044956691267
# 400 -th epoch marginal likelihood -27.120903830190056
# 450 -th epoch marginal likelihood -28.787216157859362
# 500 -th epoch marginal likelihood -30.43258923155503
# Done
#
# Proposals
# ###
# number = 1
# actions =  2444
# proposal =  [-0.12 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -13.577576078958112
# 50 -th epoch marginal likelihood -15.712514778640612
# 100 -th epoch marginal likelihood -17.75253478745181
# 150 -th epoch marginal likelihood -19.715263031240074
# 200 -th epoch marginal likelihood -21.616489284677723
# 250 -th epoch marginal likelihood -23.467843038329143
# 300 -th epoch marginal likelihood -25.27808246094584
# 350 -th epoch marginal likelihood -27.053937350219947
# 400 -th epoch marginal likelihood -28.800664543172694
# 450 -th epoch marginal likelihood -30.522428371962235
# 500 -th epoch marginal likelihood -32.222568435455806
# Done
#
# Proposals
# ###
# number = 1
# actions =  2545
# proposal =  [-0.04 -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -14.798498788870116
# 50 -th epoch marginal likelihood -16.994908355493514
# 100 -th epoch marginal likelihood -19.09445083751244
# 150 -th epoch marginal likelihood -21.11524101114934
# 200 -th epoch marginal likelihood -23.073362919334627
# 250 -th epoch marginal likelihood -24.980660714347202
# 300 -th epoch marginal likelihood -26.846059139050798
# 350 -th epoch marginal likelihood -28.67641771716109
# 400 -th epoch marginal likelihood -30.477095123846574
# 450 -th epoch marginal likelihood -32.25233648676902
# 500 -th epoch marginal likelihood -34.005546219107835
# Done
#
# Proposals
# ###
# number = 1
# actions =  2494
# proposal =  [-0.08 -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -16.057683525110765
# 50 -th epoch marginal likelihood -18.306812544843005
# 100 -th epoch marginal likelihood -20.46068925843351
# 150 -th epoch marginal likelihood -22.536175901075758
# 200 -th epoch marginal likelihood -24.54880249623423
# 250 -th epoch marginal likelihood -26.510238602036274
# 300 -th epoch marginal likelihood -28.429366035663264
# 350 -th epoch marginal likelihood -30.31305184665609
# 400 -th epoch marginal likelihood -32.16668082839681
# 450 -th epoch marginal likelihood -33.99452944073227
# 500 -th epoch marginal likelihood -35.80003306510194
# Done
#
# Proposals
# ###
# number = 1
# actions =  2544
# proposal =  [-0.04 -0.2 ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -16.46575166345285
# 50 -th epoch marginal likelihood -18.844839970349923
# 100 -th epoch marginal likelihood -21.10987580112173
# 150 -th epoch marginal likelihood -23.28726059008577
# 200 -th epoch marginal likelihood -25.398565828744555
# 250 -th epoch marginal likelihood -27.4584076767426
# 300 -th epoch marginal likelihood -29.47678926104978
# 350 -th epoch marginal likelihood -31.46065915916539
# 400 -th epoch marginal likelihood -33.414933107521314
# 450 -th epoch marginal likelihood -35.343181456993186
# 500 -th epoch marginal likelihood -37.24809968992231
# Done
#
# Proposals
# ###
# number = 1
# actions =  2588
# proposal =  [ 0.   -0.48]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -17.700820501606717
# 50 -th epoch marginal likelihood -20.134090304114185
# 100 -th epoch marginal likelihood -22.454227726977408
# 150 -th epoch marginal likelihood -24.686297746709677
# 200 -th epoch marginal likelihood -26.851082196402135
# 250 -th epoch marginal likelihood -28.962771719399232
# 300 -th epoch marginal likelihood -31.031145347163655
# 350 -th epoch marginal likelihood -33.063066381469575
# 400 -th epoch marginal likelihood -35.06349120983411
# 450 -th epoch marginal likelihood -37.03615349399691
# 500 -th epoch marginal likelihood -38.984016363115714
# Done
#
# Proposals
# ###
# number = 1
# actions =  2343
# proposal =  [-0.2  -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -18.36385613995121
# 50 -th epoch marginal likelihood -20.891768051409933
# 100 -th epoch marginal likelihood -23.293660381008024
# 150 -th epoch marginal likelihood -25.600095639292167
# 200 -th epoch marginal likelihood -27.835637209857623
# 250 -th epoch marginal likelihood -30.016786064390676
# 300 -th epoch marginal likelihood -32.15479190806145
# 350 -th epoch marginal likelihood -34.25747336425621
# 400 -th epoch marginal likelihood -36.33036443121048
# 450 -th epoch marginal likelihood -38.37744804106773
# 500 -th epoch marginal likelihood -40.401638749221576
# Done
#
# Proposals
# ###
# number = 1
# actions =  2393
# proposal =  [-0.16 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -19.736767117859273
# 50 -th epoch marginal likelihood -22.32513714435938
# 100 -th epoch marginal likelihood -24.78523922929277
# 150 -th epoch marginal likelihood -27.147848731461437
# 200 -th epoch marginal likelihood -29.437863901172143
# 250 -th epoch marginal likelihood -31.672111258725877
# 300 -th epoch marginal likelihood -33.8621270008918
# 350 -th epoch marginal likelihood -36.01596542090131
# 400 -th epoch marginal likelihood -38.13934506343078
# 450 -th epoch marginal likelihood -40.23638869940797
# 500 -th epoch marginal likelihood -42.31011547917142
# Done
#
# Proposals
# ###
# number = 1
# actions =  2443
# proposal =  [-0.12 -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -20.592335235475762
# 50 -th epoch marginal likelihood -23.26835888462258
# 100 -th epoch marginal likelihood -25.80608323288294
# 150 -th epoch marginal likelihood -28.240239931133356
# 200 -th epoch marginal likelihood -30.59826894471988
# 250 -th epoch marginal likelihood -32.898366128691514
# 300 -th epoch marginal likelihood -35.15282952296847
# 350 -th epoch marginal likelihood -37.37020120418556
# 400 -th epoch marginal likelihood -39.5565883623452
# 450 -th epoch marginal likelihood -41.71647630193429
# 500 -th epoch marginal likelihood -43.853231605013306
# Done
#
# Proposals
# ###
# number = 1
# actions =  2493
# proposal =  [-0.08 -0.2 ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -21.92960891482823
# 50 -th epoch marginal likelihood -24.671070032812462
# 100 -th epoch marginal likelihood -27.270692999400683
# 150 -th epoch marginal likelihood -29.76386315049921
# 200 -th epoch marginal likelihood -32.17866171656176
# 250 -th epoch marginal likelihood -34.533792755819164
# 300 -th epoch marginal likelihood -36.84195365279242
# 350 -th epoch marginal likelihood -39.11199764560798
# 400 -th epoch marginal likelihood -41.350273199982
# 450 -th epoch marginal likelihood -43.5614531747513
# 500 -th epoch marginal likelihood -45.74905132138218
# Done
#
# Proposals
# ###
# number = 1
# actions =  2243
# proposal =  [-0.28  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -22.99728110560003
# 50 -th epoch marginal likelihood -25.81744306255564
# 100 -th epoch marginal likelihood -28.48914210668472
# 150 -th epoch marginal likelihood -31.05006027267626
# 200 -th epoch marginal likelihood -33.52982934486798
# 250 -th epoch marginal likelihood -35.948013591620715
# 300 -th epoch marginal likelihood -38.31777977131155
# 350 -th epoch marginal likelihood -40.648249761686984
# 400 -th epoch marginal likelihood -42.94595222401975
# 450 -th epoch marginal likelihood -45.215712391692726
# 500 -th epoch marginal likelihood -47.46119646176015
# Done
#
# Proposals
# ###
# number = 1
# actions =  2293
# proposal =  [-0.24 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -24.20834000373033
# 50 -th epoch marginal likelihood -27.102603777021677
# 100 -th epoch marginal likelihood -29.84274046602734
# 150 -th epoch marginal likelihood -32.46816780128365
# 200 -th epoch marginal likelihood -35.009774130114174
# 250 -th epoch marginal likelihood -37.487881227478866
# 300 -th epoch marginal likelihood -39.91611257930733
# 350 -th epoch marginal likelihood -42.30387586195464
# 400 -th epoch marginal likelihood -44.657895195531175
# 450 -th epoch marginal likelihood -46.98314816278668
# 500 -th epoch marginal likelihood -49.28343564022181
# Done
#
# Proposals
# ###
# number = 1
# actions =  2594
# proposal =  [ 0.   -0.24]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -25.41140976825409
# 50 -th epoch marginal likelihood -28.381042576998073
# 100 -th epoch marginal likelihood -31.190571958702805
# 150 -th epoch marginal likelihood -33.88128062700411
# 200 -th epoch marginal likelihood -36.48539761120109
# 250 -th epoch marginal likelihood -39.024043026275635
# 300 -th epoch marginal likelihood -41.51131048128888
# 350 -th epoch marginal likelihood -43.95689101314682
# 400 -th epoch marginal likelihood -46.36769396140586
# 450 -th epoch marginal likelihood -48.74883625608846
# 500 -th epoch marginal likelihood -51.10424051000028
# Done
#
# Proposals
# ###
# number = 1
# actions =  2192
# proposal =  [-0.32  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -26.756519445069948
# 50 -th epoch marginal likelihood -29.793396472617047
# 100 -th epoch marginal likelihood -32.66669482600835
# 150 -th epoch marginal likelihood -35.41832533298262
# 200 -th epoch marginal likelihood -38.08114363304421
# 250 -th epoch marginal likelihood -40.67676881499353
# 300 -th epoch marginal likelihood -43.2196822288106
# 350 -th epoch marginal likelihood -45.719867947460294
# 400 -th epoch marginal likelihood -48.184451216778534
# 450 -th epoch marginal likelihood -50.61870557019563
# 500 -th epoch marginal likelihood -53.02666713134562
# Done
#
# Proposals
# ###
# number = 1
# actions =  2342
# proposal =  [-0.2  -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -27.8396710536666
# 50 -th epoch marginal likelihood -30.960916391803842
# 100 -th epoch marginal likelihood -33.91025220189257
# 150 -th epoch marginal likelihood -36.73262608065107
# 200 -th epoch marginal likelihood -39.462945395820256
# 250 -th epoch marginal likelihood -42.12395029516799
# 300 -th epoch marginal likelihood -44.730692950354545
# 350 -th epoch marginal likelihood -47.29342999501446
# 400 -th epoch marginal likelihood -49.819418169722454
# 450 -th epoch marginal likelihood -52.31401182723407
# 500 -th epoch marginal likelihood -54.78132297513215
# Done
#
# Proposals
# ###
# number = 1
# actions =  2593
# proposal =  [ 0.   -0.28]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -29.058714642734834
# 50 -th epoch marginal likelihood -32.25738915750861
# 100 -th epoch marginal likelihood -35.27768243137569
# 150 -th epoch marginal likelihood -38.166631763914815
# 200 -th epoch marginal likelihood -40.96065742339415
# 250 -th epoch marginal likelihood -43.68340146734758
# 300 -th epoch marginal likelihood -46.350433790916995
# 350 -th epoch marginal likelihood -48.97230002801885
# 400 -th epoch marginal likelihood -51.556420032818124
# 450 -th epoch marginal likelihood -54.108249809964825
# 500 -th epoch marginal likelihood -56.63197841744939
# Done
#
# Proposals
# ###
# number = 1
# actions =  2543
# proposal =  [-0.04 -0.24]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -30.18052193384709
# 50 -th epoch marginal likelihood -33.46379617408936
# 100 -th epoch marginal likelihood -36.56030727363612
# 150 -th epoch marginal likelihood -39.52016587314992
# 200 -th epoch marginal likelihood -42.38191456140165
# 250 -th epoch marginal likelihood -45.170378468284525
# 300 -th epoch marginal likelihood -47.90172923520663
# 350 -th epoch marginal likelihood -50.586780549330626
# 400 -th epoch marginal likelihood -53.23305105447884
# 450 -th epoch marginal likelihood -55.84602791946578
# 500 -th epoch marginal likelihood -58.42991924632677
# Done
#
# Proposals
# ###
# number = 1
# actions =  2442
# proposal =  [-0.12 -0.2 ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -31.61794856652309
# 50 -th epoch marginal likelihood -34.96864786652101
# 100 -th epoch marginal likelihood -38.12867196427215
# 150 -th epoch marginal likelihood -41.14878801476669
# 200 -th epoch marginal likelihood -44.068221012346335
# 250 -th epoch marginal likelihood -46.91236503970975
# 300 -th epoch marginal likelihood -49.697857550680766
# 350 -th epoch marginal likelihood -52.43588210237966
# 400 -th epoch marginal likelihood -55.13424077781183
# 450 -th epoch marginal likelihood -57.798631073769286
# 500 -th epoch marginal likelihood -60.43341362045104
# Done
#
# Proposals
# ###
# number = 1
# actions =  2341
# proposal =  [-0.2  -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -32.261499626086156
# 50 -th epoch marginal likelihood -35.72727595501421
# 100 -th epoch marginal likelihood -38.98613652662207
# 150 -th epoch marginal likelihood -42.09576133231889
# 200 -th epoch marginal likelihood -45.099979493213276
# 250 -th epoch marginal likelihood -48.02660693407576
# 300 -th epoch marginal likelihood -50.893345206884646
# 350 -th epoch marginal likelihood -53.711660782493226
# 400 -th epoch marginal likelihood -56.489250801236885
# 450 -th epoch marginal likelihood -59.23157277193444
# 500 -th epoch marginal likelihood -61.942755938764364
# Done
#
# Proposals
# ###
# number = 1
# actions =  2292
# proposal =  [-0.24 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -34.446090303341904
# 50 -th epoch marginal likelihood -38.84625316689428
# 100 -th epoch marginal likelihood -42.73313906663023
# 150 -th epoch marginal likelihood -46.19530582549505
# 200 -th epoch marginal likelihood -49.349029504848794
# 250 -th epoch marginal likelihood -52.292335638420866
# 300 -th epoch marginal likelihood -55.09653581810626
# 350 -th epoch marginal likelihood -57.80963138282419
# 400 -th epoch marginal likelihood -60.46286202334702
# 450 -th epoch marginal likelihood -63.076254107602175
# 500 -th epoch marginal likelihood -65.66245211822446
# Done
#
# Proposals
# ###
# number = 1
# actions =  2492
# proposal =  [-0.08 -0.24]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -35.62718297105761
# 50 -th epoch marginal likelihood -40.16143701153294
# 100 -th epoch marginal likelihood -44.17307372094901
# 150 -th epoch marginal likelihood -47.74644244602663
# 200 -th epoch marginal likelihood -50.99666860996915
# 250 -th epoch marginal likelihood -54.02338796286838
# 300 -th epoch marginal likelihood -56.90051257648668
# 350 -th epoch marginal likelihood -59.678482330514754
# 400 -th epoch marginal likelihood -62.39051557835006
# 450 -th epoch marginal likelihood -65.0582317638035
# 500 -th epoch marginal likelihood -67.69558801652647
# Done
#
# Proposals
# ###
# number = 1
# actions =  2391
# proposal =  [-0.16 -0.2 ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -37.412749401867224
# 50 -th epoch marginal likelihood -41.92762322707364
# 100 -th epoch marginal likelihood -45.91613678597097
# 150 -th epoch marginal likelihood -49.47556222475836
# 200 -th epoch marginal likelihood -52.72837141802714
# 250 -th epoch marginal likelihood -55.77425088989196
# 300 -th epoch marginal likelihood -58.68376096632528
# 350 -th epoch marginal likelihood -61.50364154594057
# 400 -th epoch marginal likelihood -64.26415336792
# 450 -th epoch marginal likelihood -66.98473806864081
# 500 -th epoch marginal likelihood -69.67773980497574
# Done
#
# Proposals
# ###
# number = 1
# actions =  2242
# proposal =  [-0.28 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -38.508649934488034
# 50 -th epoch marginal likelihood -43.18224895863814
# 100 -th epoch marginal likelihood -47.3191531027541
# 150 -th epoch marginal likelihood -51.00942594826478
# 200 -th epoch marginal likelihood -54.37316998363618
# 250 -th epoch marginal likelihood -57.51219289433371
# 300 -th epoch marginal likelihood -60.50077005758435
# 350 -th epoch marginal likelihood -63.389099587744624
# 400 -th epoch marginal likelihood -66.21017777471836
# 450 -th epoch marginal likelihood -68.985587887534
# 500 -th epoch marginal likelihood -71.72940292761525
# Done
#
# Proposals
# ###
# number = 1
# actions =  2542
# proposal =  [-0.04 -0.28]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!

# %% [markdown]
# ### 目的関数の推移を出力

# %%
nimo.visualization.plot_history.cycle(input_file = res_history,
                                      num_cycles = CyclesNum,
                                      fig_folder = "./fig")
