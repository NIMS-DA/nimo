# %% [markdown]
# ## NIMOハンズオン (関数の最適化)

# %%
import nimo

# %% [markdown]
# ### AIとロボットのサイクルの回数を設定

# %%
CyclesNum = 51

# %% [markdown]
# ### 目的関数の次元を設定

# %%
ObjectivesNum = 1

# %% [markdown]
# ### 実験条件候補データファイル名および提案条件のファイル名を設定

# %%
candidates_file = "./candidates_SO_Sphere.csv"

proposals_file = "./proposals.csv"

# %% [markdown]
# ### 結果を格納する場所を作成

# %%
res_history = nimo.history(input_file = candidates_file,
                             num_objectives = ObjectivesNum)

# %% [markdown]
# ### 最適化計算

# %%
for K in range(CyclesNum):

    #最初のサイクルではランダムに実験条件を提案させる
    if K == 0:
        nimo.selection(method = "RE",
                       input_file = candidates_file,
                       output_file = proposals_file,
                       num_objectives = ObjectivesNum,
                       num_proposals = 5,
                       re_seed = 111)

    #2回目以降のサイクルではAIを使用して実験条件を提案
    #PHYSBO: ベイズ最適化
    #BLOX: 無目的探索
    #PDC: 相図探索
    #RE: ランダム
    else:
        nimo.selection(method = "PHYSBO",
                       input_file = candidates_file,
                       output_file = proposals_file,
                       num_objectives = ObjectivesNum,
                       num_proposals = 1)

    #実験条件に従い，ロボット実験のインプットファイルを作成する
    #今回は，inputfile.txtファイルを作成するだけのモジュール
    import preparation_input_functions
    preparation_input_functions.Original(input_file = proposals_file,
                                         input_folder = "./").perform()


    #実験終了後，測定データを解析し，目的関数をアップデートする
    #今回は，関数値を計算し，目的関数とするanalysis_output_functions.pyを利用する
    import analysis_output_functions_SO_Sphere
    analysis_output_functions_SO_Sphere.Original(input_file = proposals_file,
                                       output_file = candidates_file,
                                       num_objectives = ObjectivesNum,
                                       output_folder = "./").perform()

    #結果をプロットするためのhistoryを格納する
    res_history = nimo.history(input_file = candidates_file,
                               num_objectives = ObjectivesNum,
                               itt = K,
                               history_file = res_history)

    #結果のヒストグラムを作成するモジュールを読み出す
    if K % 5 == 0:
        import time
        time.sleep(1)
        nimo.visualization.plot_distribution.plot(input_file = candidates_file,
                                                  num_objectives = ObjectivesNum,
                                                  fig_folder = "./fig")

    #結果の相図を作成するモジュールを読み出す
    #if K % 5 == 0:
    #    import time
    #    time.sleep(1)
    #    nimo.visualization.plot_phase_diagram.plot(input_file = candidates_file,
    #                                               fig_folder = "./fig")
# Out:
# Start selection of proposals by RE!
# Proposals
# ###
# number = 1
# actions =  871
# proposal =  [-1.32 -1.84]
# ###
# ###
# number = 2
# actions =  1294
# proposal =  [-1.   -1.24]
# ###
# ###
# number = 3
# actions =  2023
# proposal =  [-0.44 -0.64]
# ###
# ###
# number = 4
# actions =  795
# proposal =  [-1.4 -0.8]
# ###
# ###
# number = 5
# actions =  1628
# proposal =  [-0.76 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 8.294134747090624
# 50 -th epoch marginal likelihood 8.212845829226014
# 100 -th epoch marginal likelihood 8.147557899113
# 150 -th epoch marginal likelihood 8.095848195692358
# 200 -th epoch marginal likelihood 8.055382253448286
# 250 -th epoch marginal likelihood 8.023535531145187
# 300 -th epoch marginal likelihood 7.997865167321418
# 350 -th epoch marginal likelihood 7.976587561573041
# 400 -th epoch marginal likelihood 7.958592555726903
# 450 -th epoch marginal likelihood 7.943167108267868
# 500 -th epoch marginal likelihood 7.929790641982867
# Done
#
# Proposals
# ###
# number = 1
# actions =  2243
# proposal =  [-0.28  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 9.490872499588914
# 50 -th epoch marginal likelihood 9.292693008005848
# 100 -th epoch marginal likelihood 9.12445590381602
# 150 -th epoch marginal likelihood 8.988918307631481
# 200 -th epoch marginal likelihood 8.882956331036375
# 250 -th epoch marginal likelihood 8.799959373387274
# 300 -th epoch marginal likelihood 8.733319014660243
# 350 -th epoch marginal likelihood 8.677838813241511
# 400 -th epoch marginal likelihood 8.629976693916651
# 450 -th epoch marginal likelihood 8.58756464493886
# 500 -th epoch marginal likelihood 8.549361737327036
# Done
#
# Proposals
# ###
# number = 1
# actions =  2588
# proposal =  [ 0.   -0.48]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 10.675819880934107
# 50 -th epoch marginal likelihood 10.397086032075837
# 100 -th epoch marginal likelihood 10.169075117891204
# 150 -th epoch marginal likelihood 9.974086282658156
# 200 -th epoch marginal likelihood 9.802055944001298
# 250 -th epoch marginal likelihood 9.648276931758213
# 300 -th epoch marginal likelihood 9.510111258974568
# 350 -th epoch marginal likelihood 9.385471623701704
# 400 -th epoch marginal likelihood 9.272592946940684
# 450 -th epoch marginal likelihood 9.169980485023597
# 500 -th epoch marginal likelihood 9.076371559660661
# Done
#
# Proposals
# ###
# number = 1
# actions =  2600
# proposal =  [0. 0.]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 10.527051920437822
# 50 -th epoch marginal likelihood 10.114655449971487
# 100 -th epoch marginal likelihood 9.825959286328615
# 150 -th epoch marginal likelihood 9.586644673433621
# 200 -th epoch marginal likelihood 9.366509798390346
# 250 -th epoch marginal likelihood 9.161952140397716
# 300 -th epoch marginal likelihood 8.971875763540368
# 350 -th epoch marginal likelihood 8.79494581795948
# 400 -th epoch marginal likelihood 8.629810032811886
# 450 -th epoch marginal likelihood 8.475221883843389
# 500 -th epoch marginal likelihood 8.330077099342398
# Done
#
# Proposals
# ###
# number = 1
# actions =  2596
# proposal =  [ 0.   -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 9.93797875150998
# 50 -th epoch marginal likelihood 9.451087914249301
# 100 -th epoch marginal likelihood 9.100989193638734
# 150 -th epoch marginal likelihood 8.807450909847033
# 200 -th epoch marginal likelihood 8.534514590973956
# 250 -th epoch marginal likelihood 8.27751278574745
# 300 -th epoch marginal likelihood 8.035530706532477
# 350 -th epoch marginal likelihood 7.807368350707682
# 400 -th epoch marginal likelihood 7.5917365996066195
# 450 -th epoch marginal likelihood 7.387417235469621
# 500 -th epoch marginal likelihood 7.19331708105458
# Done
#
# Proposals
# ###
# number = 1
# actions =  2549
# proposal =  [-0.04  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 9.616245720138135
# 50 -th epoch marginal likelihood 9.003500006895035
# 100 -th epoch marginal likelihood 8.549200055055845
# 150 -th epoch marginal likelihood 8.178335122063604
# 200 -th epoch marginal likelihood 7.8391069400403905
# 250 -th epoch marginal likelihood 7.5175015889614505
# 300 -th epoch marginal likelihood 7.211452789263412
# 350 -th epoch marginal likelihood 6.919941321455244
# 400 -th epoch marginal likelihood 6.641800476608957
# 450 -th epoch marginal likelihood 6.3758490132917265
# 500 -th epoch marginal likelihood 6.120985576480778
# Done
#
# Proposals
# ###
# number = 1
# actions =  2396
# proposal =  [-0.16  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 9.28133838584923
# 50 -th epoch marginal likelihood 8.531245755454922
# 100 -th epoch marginal likelihood 7.959818641932286
# 150 -th epoch marginal likelihood 7.498791410679727
# 200 -th epoch marginal likelihood 7.086692723324193
# 250 -th epoch marginal likelihood 6.697594341214831
# 300 -th epoch marginal likelihood 6.325441033306699
# 350 -th epoch marginal likelihood 5.968774398561153
# 400 -th epoch marginal likelihood 5.626493616665062
# 450 -th epoch marginal likelihood 5.297446168675187
# 500 -th epoch marginal likelihood 4.980511579775069
# Done
#
# Proposals
# ###
# number = 1
# actions =  2599
# proposal =  [ 0.   -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 8.493650116108443
# 50 -th epoch marginal likelihood 7.759354830907573
# 100 -th epoch marginal likelihood 7.17640576327871
# 150 -th epoch marginal likelihood 6.646892062865147
# 200 -th epoch marginal likelihood 6.1480752209738485
# 250 -th epoch marginal likelihood 5.6768716021830805
# 300 -th epoch marginal likelihood 5.230110390009219
# 350 -th epoch marginal likelihood 4.804721445888811
# 400 -th epoch marginal likelihood 4.398013886170078
# 450 -th epoch marginal likelihood 4.007706730357419
# 500 -th epoch marginal likelihood 3.6318894976404055
# Done
#
# Proposals
# ###
# number = 1
# actions =  2598
# proposal =  [ 0.   -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 7.74942135626706
# 50 -th epoch marginal likelihood 7.003454582445792
# 100 -th epoch marginal likelihood 6.327585430139743
# 150 -th epoch marginal likelihood 5.7047544113556885
# 200 -th epoch marginal likelihood 5.125396096752745
# 250 -th epoch marginal likelihood 4.581781345842175
# 300 -th epoch marginal likelihood 4.0678942393702915
# 350 -th epoch marginal likelihood 3.5790422012603695
# 400 -th epoch marginal likelihood 3.1115320245087084
# 450 -th epoch marginal likelihood 2.6624275007225098
# 500 -th epoch marginal likelihood 2.2293710306355567
# Done
#
# Proposals
# ###
# number = 1
# actions =  2447
# proposal =  [-0.12  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 6.929695291083757
# 50 -th epoch marginal likelihood 6.10495700138262
# 100 -th epoch marginal likelihood 5.352177000331222
# 150 -th epoch marginal likelihood 4.658389896253167
# 200 -th epoch marginal likelihood 4.011887555639292
# 250 -th epoch marginal likelihood 3.4039064039690254
# 300 -th epoch marginal likelihood 2.8277962971427097
# 350 -th epoch marginal likelihood 2.278430855551578
# 400 -th epoch marginal likelihood 1.7518028802494543
# 450 -th epoch marginal likelihood 1.2447407220991096
# 500 -th epoch marginal likelihood 0.7547057500752521
# Done
#
# Proposals
# ###
# number = 1
# actions =  2498
# proposal =  [-0.08  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 6.083277295971678
# 50 -th epoch marginal likelihood 5.1702249577375285
# 100 -th epoch marginal likelihood 4.337049640458113
# 150 -th epoch marginal likelihood 3.5688462700072705
# 200 -th epoch marginal likelihood 2.852251510624935
# 250 -th epoch marginal likelihood 2.1774423037025086
# 300 -th epoch marginal likelihood 1.537047982771572
# 350 -th epoch marginal likelihood 0.9254297567879322
# 400 -th epoch marginal likelihood 0.33820373030837114
# 450 -th epoch marginal likelihood -0.22808607733511543
# 500 -th epoch marginal likelihood -0.7761976161221877
# Done
#
# Proposals
# ###
# number = 1
# actions =  2548
# proposal =  [-0.04 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 5.089029470441577
# 50 -th epoch marginal likelihood 4.110413146767463
# 100 -th epoch marginal likelihood 3.212443296788673
# 150 -th epoch marginal likelihood 2.380939992916006
# 200 -th epoch marginal likelihood 1.6026162130368533
# 250 -th epoch marginal likelihood 0.8675106622974162
# 300 -th epoch marginal likelihood 0.16807129805911636
# 350 -th epoch marginal likelihood -0.5015137479770635
# 400 -th epoch marginal likelihood -1.145779006595614
# 450 -th epoch marginal likelihood -1.7683069381028762
# 500 -th epoch marginal likelihood -2.3719601923441846
# Done
#
# Proposals
# ###
# number = 1
# actions =  2497
# proposal =  [-0.08 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 4.2560737499669905
# 50 -th epoch marginal likelihood 3.1760903514869536
# 100 -th epoch marginal likelihood 2.1875351385401833
# 150 -th epoch marginal likelihood 1.272125579532073
# 200 -th epoch marginal likelihood 0.4141821130681045
# 250 -th epoch marginal likelihood -0.3973460289435824
# 300 -th epoch marginal likelihood -1.1704818983356207
# 350 -th epoch marginal likelihood -1.911278821791698
# 400 -th epoch marginal likelihood -2.624462472513101
# 450 -th epoch marginal likelihood -3.313812629351797
# 500 -th epoch marginal likelihood -3.9823975082236647
# Done
#
# Proposals
# ###
# number = 1
# actions =  2345
# proposal =  [-0.2  0. ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 3.1785206318467782
# 50 -th epoch marginal likelihood 2.02705182144949
# 100 -th epoch marginal likelihood 0.9712693599519611
# 150 -th epoch marginal likelihood -0.007367283955135306
# 200 -th epoch marginal likelihood -0.9251547843543122
# 250 -th epoch marginal likelihood -1.7938605792045594
# 300 -th epoch marginal likelihood -2.622200987827374
# 350 -th epoch marginal likelihood -3.416808909432417
# 400 -th epoch marginal likelihood -4.182839949931745
# 450 -th epoch marginal likelihood -4.924365899583374
# 500 -th epoch marginal likelihood -5.64464344762886
# Done
#
# Proposals
# ###
# number = 1
# actions =  2547
# proposal =  [-0.04 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 2.329011686146236
# 50 -th epoch marginal likelihood 1.0881677101688556
# 100 -th epoch marginal likelihood -0.04768881377701639
# 150 -th epoch marginal likelihood -1.1013447704552677
# 200 -th epoch marginal likelihood -2.0919320927725247
# 250 -th epoch marginal likelihood -3.032607040798333
# 300 -th epoch marginal likelihood -3.9325152583358998
# 350 -th epoch marginal likelihood -4.7981810940215945
# 400 -th epoch marginal likelihood -5.634441168832285
# 450 -th epoch marginal likelihood -6.445048140255584
# 500 -th epoch marginal likelihood -7.233037776847654
# Done
#
# Proposals
# ###
# number = 1
# actions =  2597
# proposal =  [ 0.   -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 1.2629217821781769
# 50 -th epoch marginal likelihood -0.055852047282396455
# 100 -th epoch marginal likelihood -1.2632887729026514
# 150 -th epoch marginal likelihood -2.3835700660490113
# 200 -th epoch marginal likelihood -3.437115327902079
# 250 -th epoch marginal likelihood -4.438059824313793
# 300 -th epoch marginal likelihood -5.396275503237527
# 350 -th epoch marginal likelihood -6.318803027618002
# 400 -th epoch marginal likelihood -7.210827271595717
# 450 -th epoch marginal likelihood -8.076325595543064
# 500 -th epoch marginal likelihood -8.91847701869581
# Done
#
# Proposals
# ###
# number = 1
# actions =  2446
# proposal =  [-0.12 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood 0.10410858217672825
# 50 -th epoch marginal likelihood -1.291929509884918
# 100 -th epoch marginal likelihood -2.5708855436364004
# 150 -th epoch marginal likelihood -3.75796335313773
# 200 -th epoch marginal likelihood -4.8745902413730855
# 250 -th epoch marginal likelihood -5.93571396546118
# 300 -th epoch marginal likelihood -6.951863224657402
# 350 -th epoch marginal likelihood -7.930604934016411
# 400 -th epoch marginal likelihood -8.877537538423915
# 450 -th epoch marginal likelihood -9.79695470559458
# 500 -th epoch marginal likelihood -10.692269855124465
# Done
#
# Proposals
# ###
# number = 1
# actions =  2496
# proposal =  [-0.08 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -0.9538716001778642
# 50 -th epoch marginal likelihood -2.434225576418795
# 100 -th epoch marginal likelihood -3.7883781284162286
# 150 -th epoch marginal likelihood -5.044296187159894
# 200 -th epoch marginal likelihood -6.22566735123911
# 250 -th epoch marginal likelihood -7.34901306427377
# 300 -th epoch marginal likelihood -8.425924988379334
# 350 -th epoch marginal likelihood -9.464629274657295
# 400 -th epoch marginal likelihood -10.471062767840742
# 450 -th epoch marginal likelihood -11.44962369708837
# 500 -th epoch marginal likelihood -12.403689753154534
# Done
#
# Proposals
# ###
# number = 1
# actions =  2393
# proposal =  [-0.16 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -1.920807163905657
# 50 -th epoch marginal likelihood -3.4860143160095873
# 100 -th epoch marginal likelihood -4.915530010718326
# 150 -th epoch marginal likelihood -6.23997985819362
# 200 -th epoch marginal likelihood -7.485257930148156
# 250 -th epoch marginal likelihood -8.669475651451789
# 300 -th epoch marginal likelihood -9.805391345527335
# 350 -th epoch marginal likelihood -10.902073839324565
# 400 -th epoch marginal likelihood -11.966021876384595
# 450 -th epoch marginal likelihood -13.001940036417537
# 500 -th epoch marginal likelihood -14.013293142918448
# Done
#
# Proposals
# ###
# number = 1
# actions =  2395
# proposal =  [-0.16 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -3.090884659572719
# 50 -th epoch marginal likelihood -4.7391873263634
# 100 -th epoch marginal likelihood -6.243234758442089
# 150 -th epoch marginal likelihood -7.63578129382555
# 200 -th epoch marginal likelihood -8.944502568785824
# 250 -th epoch marginal likelihood -10.188789184474707
# 300 -th epoch marginal likelihood -11.382354043018088
# 350 -th epoch marginal likelihood -12.535005997076748
# 400 -th epoch marginal likelihood -13.65382958813704
# 450 -th epoch marginal likelihood -14.74398694737063
# 500 -th epoch marginal likelihood -15.809277694904663
# Done
#
# Proposals
# ###
# number = 1
# actions =  2546
# proposal =  [-0.04 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -4.351514740163578
# 50 -th epoch marginal likelihood -6.078287871656849
# 100 -th epoch marginal likelihood -7.654565334015873
# 150 -th epoch marginal likelihood -9.114139266761722
# 200 -th epoch marginal likelihood -10.485697134994766
# 250 -th epoch marginal likelihood -11.789442924721582
# 300 -th epoch marginal likelihood -13.039758942038098
# 350 -th epoch marginal likelihood -14.247011933032182
# 400 -th epoch marginal likelihood -15.418753575369326
# 450 -th epoch marginal likelihood -16.560536721329242
# 500 -th epoch marginal likelihood -17.676484890377413
# Done
#
# Proposals
# ###
# number = 1
# actions =  2294
# proposal =  [-0.24  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -5.492379428987546
# 50 -th epoch marginal likelihood -7.308277297730086
# 100 -th epoch marginal likelihood -8.963754155574033
# 150 -th epoch marginal likelihood -10.495158373588731
# 200 -th epoch marginal likelihood -11.93325795746064
# 250 -th epoch marginal likelihood -13.29969290597366
# 300 -th epoch marginal likelihood -14.609866383466157
# 350 -th epoch marginal likelihood -15.874901987808109
# 400 -th epoch marginal likelihood -17.102939126116702
# 450 -th epoch marginal likelihood -18.300004557495853
# 500 -th epoch marginal likelihood -19.470607922900264
# Done
#
# Proposals
# ###
# number = 1
# actions =  2445
# proposal =  [-0.12 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -6.697408875238027
# 50 -th epoch marginal likelihood -8.602637406754674
# 100 -th epoch marginal likelihood -10.33743831592226
# 150 -th epoch marginal likelihood -11.940620260255374
# 200 -th epoch marginal likelihood -13.444974198481308
# 250 -th epoch marginal likelihood -14.873543017029828
# 300 -th epoch marginal likelihood -16.24272772652021
# 350 -th epoch marginal likelihood -17.56438724510914
# 400 -th epoch marginal likelihood -18.847226734953153
# 450 -th epoch marginal likelihood -20.09772945761728
# 500 -th epoch marginal likelihood -21.32078909175307
# Done
#
# Proposals
# ###
# number = 1
# actions =  2495
# proposal =  [-0.08 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -7.9356699617234945
# 50 -th epoch marginal likelihood -9.928890742907097
# 100 -th epoch marginal likelihood -11.742253825867698
# 150 -th epoch marginal likelihood -13.416780049577932
# 200 -th epoch marginal likelihood -14.987105357431982
# 250 -th epoch marginal likelihood -16.47756467165324
# 300 -th epoch marginal likelihood -17.905484333326186
# 350 -th epoch marginal likelihood -19.283404606324495
# 400 -th epoch marginal likelihood -20.620548630544917
# 450 -th epoch marginal likelihood -21.92380873488576
# 500 -th epoch marginal likelihood -23.19841572214291
# Done
#
# Proposals
# ###
# number = 1
# actions =  2545
# proposal =  [-0.04 -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -9.09546152384044
# 50 -th epoch marginal likelihood -11.186542936276386
# 100 -th epoch marginal likelihood -13.085606951810988
# 150 -th epoch marginal likelihood -14.836809719190871
# 200 -th epoch marginal likelihood -16.47732297769557
# 250 -th epoch marginal likelihood -18.033194382295008
# 300 -th epoch marginal likelihood -19.52291677980146
# 350 -th epoch marginal likelihood -20.959838054462896
# 400 -th epoch marginal likelihood -22.353754627538883
# 450 -th epoch marginal likelihood -23.71198132700749
# 500 -th epoch marginal likelihood -25.04007656142877
# Done
#
# Proposals
# ###
# number = 1
# actions =  2444
# proposal =  [-0.12 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -10.472507759938672
# 50 -th epoch marginal likelihood -12.643338639598666
# 100 -th epoch marginal likelihood -14.615582689254449
# 150 -th epoch marginal likelihood -16.434628117652103
# 200 -th epoch marginal likelihood -18.138766443562076
# 250 -th epoch marginal likelihood -19.754893586207704
# 300 -th epoch marginal likelihood -21.30216343655457
# 350 -th epoch marginal likelihood -22.794448119168443
# 400 -th epoch marginal likelihood -24.24196250511946
# 450 -th epoch marginal likelihood -25.652355669810373
# 500 -th epoch marginal likelihood -27.031452895080704
# Done
#
# Proposals
# ###
# number = 1
# actions =  2394
# proposal =  [-0.16 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -11.506497779736685
# 50 -th epoch marginal likelihood -13.795699105514368
# 100 -th epoch marginal likelihood -15.869119937493561
# 150 -th epoch marginal likelihood -17.77707223094102
# 200 -th epoch marginal likelihood -19.561739785379903
# 250 -th epoch marginal likelihood -21.252567519221007
# 300 -th epoch marginal likelihood -22.87035423941989
# 350 -th epoch marginal likelihood -24.43002249874899
# 400 -th epoch marginal likelihood -25.94245607099507
# 450 -th epoch marginal likelihood -27.4157367956815
# 500 -th epoch marginal likelihood -28.85598310852091
# Done
#
# Proposals
# ###
# number = 1
# actions =  2344
# proposal =  [-0.2  -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -11.499509048400155
# 50 -th epoch marginal likelihood -13.994244443981115
# 100 -th epoch marginal likelihood -16.234330033249357
# 150 -th epoch marginal likelihood -18.282521992222737
# 200 -th epoch marginal likelihood -20.190940411021103
# 250 -th epoch marginal likelihood -21.995571096378406
# 300 -th epoch marginal likelihood -23.72132053151263
# 350 -th epoch marginal likelihood -25.385497829277394
# 400 -th epoch marginal likelihood -27.00018507755599
# 450 -th epoch marginal likelihood -28.573887503902732
# 500 -th epoch marginal likelihood -30.11269414193451
# Done
#
# Proposals
# ###
# number = 1
# actions =  2595
# proposal =  [ 0.  -0.2]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -13.817476337347744
# 50 -th epoch marginal likelihood -16.32480275101154
# 100 -th epoch marginal likelihood -18.588953036522877
# 150 -th epoch marginal likelihood -20.667418044411406
# 200 -th epoch marginal likelihood -22.608296068980415
# 250 -th epoch marginal likelihood -24.44507440101727
# 300 -th epoch marginal likelihood -26.201295822737507
# 350 -th epoch marginal likelihood -27.89373289748689
# 400 -th epoch marginal likelihood -29.534508752127103
# 450 -th epoch marginal likelihood -31.132536859401867
# 500 -th epoch marginal likelihood -32.6945048623874
# Done
#
# Proposals
# ###
# number = 1
# actions =  2494
# proposal =  [-0.08 -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -14.07100349066367
# 50 -th epoch marginal likelihood -16.76552980170044
# 100 -th epoch marginal likelihood -19.184173899325412
# 150 -th epoch marginal likelihood -21.394227177739857
# 200 -th epoch marginal likelihood -23.45188052930012
# 250 -th epoch marginal likelihood -25.39613453772288
# 300 -th epoch marginal likelihood -27.25415601155646
# 350 -th epoch marginal likelihood -29.044964000379913
# 400 -th epoch marginal likelihood -30.781933287134397
# 450 -th epoch marginal likelihood -32.47453677342871
# 500 -th epoch marginal likelihood -34.12957629776423
# Done
#
# Proposals
# ###
# number = 1
# actions =  2557
# proposal =  [ 0.   -1.72]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -7.867927552062465
# 50 -th epoch marginal likelihood -11.844109248682884
# 100 -th epoch marginal likelihood -15.311795179039315
# 150 -th epoch marginal likelihood -18.33441253134175
# 200 -th epoch marginal likelihood -20.987782388957996
# 250 -th epoch marginal likelihood -23.346895566929632
# 300 -th epoch marginal likelihood -25.480548366338148
# 350 -th epoch marginal likelihood -27.445313594922276
# 400 -th epoch marginal likelihood -29.28418766100239
# 450 -th epoch marginal likelihood -31.02858926664939
# 500 -th epoch marginal likelihood -32.701300129025455
# Done
#
# Proposals
# ###
# number = 1
# actions =  2293
# proposal =  [-0.24 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -12.75081348407807
# 50 -th epoch marginal likelihood -15.527271668765755
# 100 -th epoch marginal likelihood -18.030853968844713
# 150 -th epoch marginal likelihood -20.32649683547347
# 200 -th epoch marginal likelihood -22.46885803954316
# 250 -th epoch marginal likelihood -24.49618070914422
# 300 -th epoch marginal likelihood -26.435406715638177
# 350 -th epoch marginal likelihood -28.305701734457408
# 400 -th epoch marginal likelihood -30.120843255972925
# 450 -th epoch marginal likelihood -31.89086745601221
# 500 -th epoch marginal likelihood -33.62321223286304
# Done
#
# Proposals
# ###
# number = 1
# actions =  2544
# proposal =  [-0.04 -0.2 ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -14.03528488785663
# 50 -th epoch marginal likelihood -16.907836797266583
# 100 -th epoch marginal likelihood -19.497155393721926
# 150 -th epoch marginal likelihood -21.87047738992218
# 200 -th epoch marginal likelihood -24.0845025840486
# 250 -th epoch marginal likelihood -26.17896653251088
# 300 -th epoch marginal likelihood -28.181906781211342
# 350 -th epoch marginal likelihood -30.113294930414025
# 400 -th epoch marginal likelihood -31.987498527047443
# 450 -th epoch marginal likelihood -33.814982423178996
# 500 -th epoch marginal likelihood -35.603494410467505
# Done
#
# Proposals
# ###
# number = 1
# actions =  2443
# proposal =  [-0.12 -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -14.791826077420117
# 50 -th epoch marginal likelihood -17.810390491178694
# 100 -th epoch marginal likelihood -20.52210259481502
# 150 -th epoch marginal likelihood -23.000130866551864
# 200 -th epoch marginal likelihood -25.306563686490726
# 250 -th epoch marginal likelihood -27.485104394743956
# 300 -th epoch marginal likelihood -29.56662811127986
# 350 -th epoch marginal likelihood -31.573056164912114
# 400 -th epoch marginal likelihood -33.52001404810481
# 450 -th epoch marginal likelihood -35.4187016151809
# 500 -th epoch marginal likelihood -37.277230040047456
# Done
#
# Proposals
# ###
# number = 1
# actions =  2594
# proposal =  [ 0.   -0.24]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -14.391619695914805
# 50 -th epoch marginal likelihood -17.642257172199496
# 100 -th epoch marginal likelihood -20.546555472760225
# 150 -th epoch marginal likelihood -23.186153695884563
# 200 -th epoch marginal likelihood -25.6314300114
# 250 -th epoch marginal likelihood -27.93267005716949
# 300 -th epoch marginal likelihood -30.125953165346186
# 350 -th epoch marginal likelihood -32.23725369077499
# 400 -th epoch marginal likelihood -34.285236647872466
# 450 -th epoch marginal likelihood -36.28322203488776
# 500 -th epoch marginal likelihood -38.24061278101536
# Done
#
# Proposals
# ###
# number = 1
# actions =  2392
# proposal =  [-0.16 -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -16.61802831210055
# 50 -th epoch marginal likelihood -19.899030478888662
# 100 -th epoch marginal likelihood -22.83774525515621
# 150 -th epoch marginal likelihood -25.51482937483792
# 200 -th epoch marginal likelihood -27.999569381569536
# 250 -th epoch marginal likelihood -30.341279316603035
# 300 -th epoch marginal likelihood -32.57517995175435
# 350 -th epoch marginal likelihood -34.72650959550838
# 400 -th epoch marginal likelihood -36.813345047506836
# 450 -th epoch marginal likelihood -38.848597324624265
# 500 -th epoch marginal likelihood -40.84146537052298
# Done
#
# Proposals
# ###
# number = 1
# actions =  2593
# proposal =  [ 0.   -0.28]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -16.068269392058756
# 50 -th epoch marginal likelihood -20.5482531209181
# 100 -th epoch marginal likelihood -24.466918265407912
# 150 -th epoch marginal likelihood -27.8936041620775
# 200 -th epoch marginal likelihood -30.925131843788222
# 250 -th epoch marginal likelihood -33.65384073674565
# 300 -th epoch marginal likelihood -36.155987000639655
# 350 -th epoch marginal likelihood -38.48844690023898
# 400 -th epoch marginal likelihood -40.69167245317735
# 450 -th epoch marginal likelihood -42.79445819575328
# 500 -th epoch marginal likelihood -44.81803264741627
# Done
#
# Proposals
# ###
# number = 1
# actions =  2543
# proposal =  [-0.04 -0.24]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -17.249906255876077
# 50 -th epoch marginal likelihood -21.863012237909324
# 100 -th epoch marginal likelihood -25.90309116735587
# 150 -th epoch marginal likelihood -29.43944451377861
# 200 -th epoch marginal likelihood -32.57028441211421
# 250 -th epoch marginal likelihood -35.38993088583469
# 300 -th epoch marginal likelihood -37.9764910818259
# 350 -th epoch marginal likelihood -40.38818967691124
# 400 -th epoch marginal likelihood -42.6663013921311
# 450 -th epoch marginal likelihood -44.840074702156386
# 500 -th epoch marginal likelihood -46.93102244917301
# Done
#
# Proposals
# ###
# number = 1
# actions =  2343
# proposal =  [-0.2  -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -18.28166885764855
# 50 -th epoch marginal likelihood -23.06140803901786
# 100 -th epoch marginal likelihood -27.254173053220523
# 150 -th epoch marginal likelihood -30.928525518624152
# 200 -th epoch marginal likelihood -34.18214760835781
# 250 -th epoch marginal likelihood -37.11068475658635
# 300 -th epoch marginal likelihood -39.794902113289716
# 350 -th epoch marginal likelihood -42.295757319870184
# 400 -th epoch marginal likelihood -44.65659271543973
# 450 -th epoch marginal likelihood -46.90792577261956
# 500 -th epoch marginal likelihood -49.07193806515481
# Done
#
# Proposals
# ###
# number = 1
# actions =  2493
# proposal =  [-0.08 -0.2 ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -20.08096142770855
# 50 -th epoch marginal likelihood -24.87938183248768
# 100 -th epoch marginal likelihood -29.085868470589382
# 150 -th epoch marginal likelihood -32.77381101583414
# 200 -th epoch marginal likelihood -36.04762368930084
# 250 -th epoch marginal likelihood -39.00571988699337
# 300 -th epoch marginal likelihood -41.72774032154341
# 350 -th epoch marginal likelihood -44.27189248633002
# 400 -th epoch marginal likelihood -46.67888733572059
# 450 -th epoch marginal likelihood -48.97748330827128
# 500 -th epoch marginal likelihood -51.18906082721905
# Done
#
# Proposals
# ###
# number = 1
# actions =  2442
# proposal =  [-0.12 -0.2 ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -21.380194748364136
# 50 -th epoch marginal likelihood -26.300116890027777
# 100 -th epoch marginal likelihood -30.61718187453213
# 150 -th epoch marginal likelihood -34.405253504309016
# 200 -th epoch marginal likelihood -37.770126051346814
# 250 -th epoch marginal likelihood -40.812058072561484
# 300 -th epoch marginal likelihood -43.61242759489144
# 350 -th epoch marginal likelihood -46.230704465422086
# 400 -th epoch marginal likelihood -48.708345761908376
# 450 -th epoch marginal likelihood -51.07448687064664
# 500 -th epoch marginal likelihood -53.350712482162876
# Done
#
# Proposals
# ###
# number = 1
# actions =  2342
# proposal =  [-0.2  -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -22.887525250293063
# 50 -th epoch marginal likelihood -27.885976785088467
# 100 -th epoch marginal likelihood -32.27265101610775
# 150 -th epoch marginal likelihood -36.12464944658606
# 200 -th epoch marginal likelihood -39.55165265449676
# 250 -th epoch marginal likelihood -42.65590042137185
# 300 -th epoch marginal likelihood -45.51896296865845
# 350 -th epoch marginal likelihood -48.19963900228653
# 400 -th epoch marginal likelihood -50.738591288753604
# 450 -th epoch marginal likelihood -53.16442427860834
# 500 -th epoch marginal likelihood -55.498571641111845
# Done
#
# Proposals
# ###
# number = 1
# actions =  2292
# proposal =  [-0.24 -0.08]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -24.095087145320498
# 50 -th epoch marginal likelihood -29.234569728467246
# 100 -th epoch marginal likelihood -33.74984346122773
# 150 -th epoch marginal likelihood -37.71799054429226
# 200 -th epoch marginal likelihood -41.24964771638809
# 250 -th epoch marginal likelihood -44.44900096787862
# 300 -th epoch marginal likelihood -47.39981949647837
# 350 -th epoch marginal likelihood -50.1626541375844
# 400 -th epoch marginal likelihood -52.77924297406486
# 450 -th epoch marginal likelihood -55.27870881485193
# 500 -th epoch marginal likelihood -57.682708259482126
# Done
#
# Proposals
# ###
# number = 1
# actions =  2341
# proposal =  [-0.2  -0.16]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -25.48396819803508
# 50 -th epoch marginal likelihood -30.730206429112496
# 100 -th epoch marginal likelihood -35.341907582736766
# 150 -th epoch marginal likelihood -39.397838220666515
# 200 -th epoch marginal likelihood -43.01093968537248
# 250 -th epoch marginal likelihood -46.28725662347735
# 300 -th epoch marginal likelihood -49.31169925055385
# 350 -th epoch marginal likelihood -52.145344193399936
# 400 -th epoch marginal likelihood -54.8300806611204
# 450 -th epoch marginal likelihood -57.39505016606358
# 500 -th epoch marginal likelihood -59.86197350414587
# Done
#
# Proposals
# ###
# number = 1
# actions =  2492
# proposal =  [-0.08 -0.24]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -26.79802554870971
# 50 -th epoch marginal likelihood -32.16924258438557
# 100 -th epoch marginal likelihood -36.89498884839428
# 150 -th epoch marginal likelihood -41.05434287168406
# 200 -th epoch marginal likelihood -44.76186636957279
# 250 -th epoch marginal likelihood -48.12560401757835
# 300 -th epoch marginal likelihood -51.23215997503871
# 350 -th epoch marginal likelihood -54.143708171563915
# 400 -th epoch marginal likelihood -56.902683570393634
# 450 -th epoch marginal likelihood -59.53843190191705
# 500 -th epoch marginal likelihood -62.07277490808703
# Done
#
# Proposals
# ###
# number = 1
# actions =  2192
# proposal =  [-0.32  0.  ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -28.679192141368752
# 50 -th epoch marginal likelihood -34.05594885796099
# 100 -th epoch marginal likelihood -38.782501132774755
# 150 -th epoch marginal likelihood -42.94657972803846
# 200 -th epoch marginal likelihood -46.670183808533686
# 250 -th epoch marginal likelihood -50.062160476178576
# 300 -th epoch marginal likelihood -53.20545530734245
# 350 -th epoch marginal likelihood -56.15764926593715
# 400 -th epoch marginal likelihood -58.95780284645436
# 450 -th epoch marginal likelihood -61.63380738109892
# 500 -th epoch marginal likelihood -64.20766490240149
# Done
#
# Proposals
# ###
# number = 1
# actions =  2391
# proposal =  [-0.16 -0.2 ]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -29.811832560435697
# 50 -th epoch marginal likelihood -35.35505021836538
# 100 -th epoch marginal likelihood -40.23435984089953
# 150 -th epoch marginal likelihood -44.53523135831331
# 200 -th epoch marginal likelihood -48.37928278144095
# 250 -th epoch marginal likelihood -51.87780070223228
# 300 -th epoch marginal likelihood -55.11733537961215
# 350 -th epoch marginal likelihood -58.15857967786698
# 400 -th epoch marginal likelihood -61.04252453966995
# 450 -th epoch marginal likelihood -63.79787775541483
# 500 -th epoch marginal likelihood -66.44678663952267
# Done
#
# Proposals
# ###
# number = 1
# actions =  2242
# proposal =  [-0.28 -0.04]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -31.377483588407614
# 50 -th epoch marginal likelihood -37.00097625796498
# 100 -th epoch marginal likelihood -41.952164608977796
# 150 -th epoch marginal likelihood -46.32038109922163
# 200 -th epoch marginal likelihood -50.23100829538648
# 250 -th epoch marginal likelihood -53.79660650240869
# 300 -th epoch marginal likelihood -57.10312214314753
# 350 -th epoch marginal likelihood -60.20998429685258
# 400 -th epoch marginal likelihood -63.15712332086625
# 450 -th epoch marginal likelihood -65.97280023393893
# 500 -th epoch marginal likelihood -68.67935127173672
# Done
#
# Proposals
# ###
# number = 1
# actions =  2542
# proposal =  [-0.04 -0.28]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -32.78290644663786
# 50 -th epoch marginal likelihood -38.5212239798565
# 100 -th epoch marginal likelihood -43.576355060329725
# 150 -th epoch marginal likelihood -48.039289090333966
# 200 -th epoch marginal likelihood -52.038071087967836
# 250 -th epoch marginal likelihood -55.687193979433495
# 300 -th epoch marginal likelihood -59.073549183682985
# 350 -th epoch marginal likelihood -62.256792939804214
# 400 -th epoch marginal likelihood -65.27674515247837
# 450 -th epoch marginal likelihood -68.16156041798588
# 500 -th epoch marginal likelihood -70.93367822516154
# Done
#
# Proposals
# ###
# number = 1
# actions =  2441
# proposal =  [-0.12 -0.24]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!
# Start selection of proposals by PHYSBO!
# Start the initial hyper parameter searching ...
# Done
#
# Start the hyper parameter learning ...
# 0 -th epoch marginal likelihood -33.864037300521666
# 50 -th epoch marginal likelihood -39.78466717986828
# 100 -th epoch marginal likelihood -45.00775827559421
# 150 -th epoch marginal likelihood -49.62079605018667
# 200 -th epoch marginal likelihood -53.7507311279481
# 250 -th epoch marginal likelihood -57.51473543375246
# 300 -th epoch marginal likelihood -61.004067776853134
# 350 -th epoch marginal likelihood -64.2822796130467
# 400 -th epoch marginal likelihood -67.39162559861434
# 450 -th epoch marginal likelihood -70.36121957928135
# 500 -th epoch marginal likelihood -73.2135209513922
# Done
#
# Proposals
# ###
# number = 1
# actions =  2291
# proposal =  [-0.24 -0.12]
# ###
# Finish selection of proposals!
# Start preparation input!
# Finish preparation input!
# Start analysis output!
# Finish analysis output!

# %% [markdown]
# ### 目的関数の推移を出力

# %%
nimo.visualization.plot_history.cycle(input_file = res_history,
                                      num_cycles = CyclesNum,
                                      fig_folder = "./fig")
